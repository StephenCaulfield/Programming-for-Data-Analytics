# %% [markdown]
# # Programming-for-Data-Analysis-Project-2022
# ===============================================================================================================================
#
# # 1.Introduction
#
# <p> For This Project I will be sythesizing a data set which details the sinking of the Titanic and analyzing the survival rate of people based on age, gender and class and their relationships to eachother. I will detail later in my investigation that I have done to substanciate my findings.</p>
#
# ## 1.1 Project Statement
#
# * This project code and report is implemented on Jupyter notebook.
# * I am to create a synthesized or simulated data set using a real world phenomenon of my choosing(Survivors of the Titanic).
# * I will use python with the numpy package to create the distribution models.
# * I will determine what distribution models I should use through research on the topic.
# * I will discuss the output of my analysis a make a determination as to it's significance.
#
# ## 1.2 Reasons for Simulating Data
#
# <p>I will detail the advantages and disadvantages of simulating a data set to imitate social phenomon.</p>
#
# #### Advantages
#
# * It gives a more detailed and unique perspective of the phenomenon, allowing us to precisely analyse what the outcomes are instead of making baseless presumptions.
#
# * It can predict how people will behave in potentially similar events.
#
# * It can help professionals develop law's, new technologies and philosophies that help improve our lives(e.g. increase survival rate of ship passengers)
#
# * Simulating these events is risk-free(No need to sink a ship for data analysis)
#
# #### Disadvantages
#
# * Researcher-induced bias can potentially cause wildly different interpretations of the data.
#
# * A subjective analysis is necessary to derive meaning from the data set in social phenomenons.
#
# * Social phenomonons can change over time due to cultural and technological differences which can make these simulations appear dated very quickly.
#
# _______________________________________________________________________________________________________________________________
#
#
# # 2. The Topic
#
#
#
# ## 2.1 A Brief History of the Titanic.
#
# <p>
# <img src="Images\titanic_built.jpg" alt="Titanic being built" width="280" align = "right"/>
# The Titanic was a British Passenger Liner built in Belfast in 1912. The ship had gained notoriety due to claims of it being "unsinkable", though shipbuilders claim it had not been marketed as such, It had then sank on its maiden voyage due to striking an iceberg in the North Atlantic Ocean.
# </p>
# <p>
# It had a total capacity of 3,327 passengers and crew(3,547 according to other sources.) though it carried a total of 2,224 passengers and crew on its maiden voyage of which Only 710 of those aboard survived and 1514 passengers had lost there lives on that voyage.
# </p>
# <p>
# This project will synthesize a data set detailing the fates of those passengers.
# </p>
#
#
#
# ## 2.2 Explaining the Data Set
# <span style="color:blue">Blue</span> = Relevant to analysis. |<span style="color:red"> Red</span> = Not Relevant to analysis. |<span style="color:orange"> Orange</span> = May be somewhat releavant to analysis.
#
# * <span style="color:orange">PassengerId</span>: An integer identifier for each passenger. This is not incredibly relevant for analysis.
#
# * <span style="color:blue">Survived</span>: A boolean detailing whether the passenger survived or not, 1 means they survived, 0 if they did not. This will be relevant for analysis
#
# * <span style="color:blue">Pclass</span>: An Integer that indicates what class the passenger between 1st, 2nd and 3rd class is, 1st being the highest, 3rd being lowest. This will be relevant for analysis.
#
# * <span style="color:red">Name</span>: A string that details the name of each passenger. This will not be relevant for analysis.
#
# * <span style="color:blue">Sex</span>: A string that details the sex of the passenger between male and female. This will be relevant for analysis.
#
# * <span style="color:blue">Age</span>: A double that details the age of each passenger. This will be relevant for analysis.
#
# * <span style="color:blue">SibSp</span>: An integer detailing how many siblings and spouses each passenger had onboard. This will be relevant to the analysis.
#
# * <span style="color:blue">Parch</span>: An integer that details the number of parents or children a passenger has onboard. This will be relevant to the analysis.
#
# * <span style="color:red">Ticket</span>: A string that details the ID of the ticket used by the passenger. This will not be relevant for analysis.
#
# * <span style="color:orange">Fare</span>: A double that details the money they paid to board the Titanic. This may be relevant to the analysis.
#
# * <span style="color:red">Cabin</span>: A string that details what cabin they were assigned to. This is not relevant to the analysis.
#
# * <span style="color:blue">Embarked</span>: A character detailing where the passenger boarded the ship from, S for Southampton, C for Cherbourg and Q for Queenstown. This will be relevant to the analysis.
#
# <p> This particular data contains a total of 891 entries so the scope is only fraction of the total passengers on board.</p>
#
# <p>The main areas of analysis will be on the survival rates of different demographics(e.g. age, sex and class) and presenting that data using relevant distribution models</p>
#
# <p>One thing to note with this analysis is that it is based on human behaviour, which can be influenced through many different social factors such as culture and environment which change with time, unlike the tossing of a coin which will virtually guarantee identical results every time short of someone changing what a coin is.</p>
#
# _______________________________________________________________________________________________________________________________
#
# # 3. Setting Up
#
# ## 3.1 Tools and Platforms Used
#
# - Programming Language
#
#     - Python
#
#         - Packages
#
#             - Numpy
#
#             - Matplotlib
#
#             - Pandas
#
#             - Seaborn
#
#             - csv
#
#
# - Github
#
#     - Gist
#
#          - titanic-dataset.csv [1]
#
# ## 3.2 Import Packages

# %%
#Packages Required

import numpy as np

import matplotlib.pyplot as plt

from  matplotlib.ticker import FuncFormatter

import pandas as pd

import seaborn as sns

import csv

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 3.3 Creating data sets.

# %%
#Reads in csv file and creates table
passengers = pd.read_csv("titanic_dataset.csv")

#displays passengers table first and last 5 entries
passengers
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# This table contains many elements that are not need as described above in section 2.2. I will use code to remove them and create a new dataframe called 'df'.

# %%
#Recreates the table passengers but removes the specified columns
df = passengers.drop(["PassengerId", "Name", "Ticket", "Fare", "Cabin", "SibSp", "Parch"], axis = 1)
print("Columns of set with correlative factors.")
df
# Out:
# Columns of set with correlative factors.
#      Survived  Pclass     Sex   Age Embarked
# 0           0       3    male  22.0        S
# 1           1       1  female  38.0        C
# 2           1       3  female  26.0        S
# 3           1       1  female  35.0        S
# 4           0       3    male  35.0        S
# ..        ...     ...     ...   ...      ...
# 886         0       2    male  27.0        S
# 887         1       1  female  19.0        S
# 888         0       3  female   NaN        S
# 889         1       1    male  26.0        C
# 890         0       3    male  32.0        Q
#
# [891 rows x 5 columns]

# %% [raw]
# <p>Here I am renaming the Pclass column and each Embarked entry to make more sense.</p>
# <p>I also decided to change the 'Sex' and 'Embarked' Values into floats, with male being 1 and female 0, functioning like a boolean, and in 'Embarked' I changed S, C, Q to 1, 2, 3 resepectively.</p>
# <p> This is to make it easier to synthesise the simulation.</p>

# %%
df = df.rename(columns = {
    "Pclass" : 'Class'
})
df['Embarked'].loc[(df['Embarked'] == 'S')] = 1
df['Embarked'].loc[(df['Embarked'] == 'C')] = 2
df['Embarked'].loc[(df['Embarked'] == 'Q')] = 3
df['Sex'].loc[(df['Sex'] == 'male')] = int(1)
df['Sex'].loc[(df['Sex'] == 'female')] = int(0)
df['Sex'] = df['Sex'].convert_dtypes('int32')
df['Embarked'] = df['Embarked'].convert_dtypes('int32')
df
# Out:
#      Survived  Class  Sex   Age  Embarked
# 0           0      3    1  22.0         1
# 1           1      1    0  38.0         2
# 2           1      3    0  26.0         1
# 3           1      1    0  35.0         1
# 4           0      3    1  35.0         1
# ..        ...    ...  ...   ...       ...
# 885         0      3    0  39.0         3
# 886         0      2    1  27.0         1
# 887         1      1    0  19.0         1
# 889         1      1    1  26.0         2
# 890         0      3    1  32.0         3
#
# [712 rows x 5 columns]

# %%
#Prints the count, mean, standard deviation, minimum, maximum and 25th, 50th and 75th percentiles.
df.describe()
# Out:
#          Survived       Class       Sex         Age    Embarked
# count  712.000000  712.000000     712.0  712.000000  712.000000
# mean     0.404494    2.240169  0.636236   29.642093    1.261236
# std      0.491139    0.836854   0.48142   14.492933    0.521561
# min      0.000000    1.000000       0.0    0.420000    1.000000
# 25%      0.000000    1.000000       0.0   20.000000    1.000000
# 50%      0.000000    2.000000       1.0   28.000000    1.000000
# 75%      1.000000    3.000000       1.0   38.000000    1.000000
# max      1.000000    3.000000       1.0   80.000000    3.000000

# %% [markdown]
# <p>Something to note here is that Age is the only quantitive factor while Survived is akin to a boolean and class being a description, but the data is useful nonetheless.</p>
# <p>In the age column we see that there are missing values, we can use isna() to determine how many missing values there are.</p>

# %%
#Counts missing values in each row.
df.isna().sum()
# Out:
# Survived      0
# Class         0
# Sex           0
# Age         177
# Embarked      2
# dtype: int64

# %% [markdown]
# There are also 2 missing values in Embarked.
# <p>With this in mind, I made the decision to remove any rows with missing values as they will scew the simulation unnecessarily. Only 100 data points are needed so this should be appropriate</p>

# %%
df.dropna(inplace = True)                   
df.describe()
# Out:
#          Survived       Class         Sex         Age    Embarked
# count  712.000000  712.000000  712.000000  712.000000  712.000000
# mean     0.404494    2.240169    0.636236   29.642093    1.261236
# std      0.491139    0.836854    0.481420   14.492933    0.521561
# min      0.000000    1.000000    0.000000    0.420000    1.000000
# 25%      0.000000    1.000000    0.000000   20.000000    1.000000
# 50%      0.000000    2.000000    1.000000   28.000000    1.000000
# 75%      1.000000    3.000000    1.000000   38.000000    1.000000
# max      1.000000    3.000000    1.000000   80.000000    3.000000

# %% [markdown]
# ## 3.4 Simulating the Data Set
# <p> For the purposes of this project I will be using numpy.random to simulate the data set and then analyse the findings.<p>

# %%
#Total number of survivors and deaths.
survivors = pd.Series(df["Survived"]).value_counts()
print("NUMBER OF SURVIVORS AND DEATHS")
print("Survived: ", survivors.get(1), "| Deaths: ", survivors.get(0),"\n")

#Total number of Male and Female Passengers.
sex = pd.Series(df["Sex"]).value_counts()
print("NUMBER OF MALES AND FEMALES")
print("Male: ", sex.get("male"), "| Female: ", sex.get("female"),"\n")

#Number of people with x siblings and spouses.
SibSp = pd.Series(df["SibSp"]).value_counts()
print("NUMBER OF SIBLINGS AND SPOUSES ONBOARD")
print("Zero: ", SibSp.get(0), "| One: ", SibSp.get(1) , "| Two: ", SibSp.get(2), "| Three: ", SibSp.get(3), "| Four: ", SibSp.get(4), "| Five: ", SibSp.get(5), "| Six: ", SibSp.get(6),"\n"
)

#Number of people with x siblings and spouses.
Parch = pd.Series(df["Parch"]).value_counts()
print("NUMBER OF PARENTS AND CHILDREN ONBOARD")
print("Zero: ", Parch.get(0), "| One: ", Parch.get(1) , "| Two: ", Parch.get(2), "| Three: ", Parch.get(3), "| Four: ", Parch.get(4), "| Five: ", Parch.get(5), "| Six: ", Parch.get(6),"\n")

#Average Age of all passengers.
avg_age = df["Age"].sum()/len(df["Age"])
print("Average age: ", avg_age)
# Out:
# NUMBER OF SURVIVORS AND DEATHS
# Survived:  288 | Deaths:  424
#
# NUMBER OF MALES AND FEMALES
# Male:  None | Female:  None
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\indexes\base.py:3803, in Index.get_loc(self, key, method, tolerance)
#    3802 try:
# -> 3803     return self._engine.get_loc(casted_key)
#    3804 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...

# %%
age_totals = df["Age"].value_counts()
sns.histplot(data = df["Age"], kde = True)
plt.title("Age of Passengers")
# Out:
# Text(0.5, 1.0, 'Age of Passengers')

# %%
def Survival_Breakdown(column):
    sns.countplot(data = df["Survived"], x = column, hue = "Sex")
    plt.show()
    print(df[column].value_counts())
    split = sns.FacetGrid(df, col = column)
    split.map(sns.countplot,"Survived", alpha = .8)
    plt.show()

# %%
Survival_Breakdown("Pclass")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 Survival_Breakdown("Pclass")
#
# Cell In[9], line 2, in Survival_Breakdown(column)
#       1 def Survival_Breakdown(column):
# ----> 2     sns.countplot(data = passengers["Survived"], x = column, hue = "Sex")
#       3     plt.show()
#       4     print(passengers[column].value_counts())
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:2942, in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2939 elif x is not None and y is not None:
#    2940     raise ValueError("Cannot pass values for both `x` and `y`")
# -> 2942 plotter = _CountPlotter(
#    2943     x, y, hue, data, order, hue_order,
#    2944     estimator, errorbar, n_boot, units, seed,
#    2945     orient, color, palette, saturation,
# ...

# %%
Survival_Breakdown("Age")

# %%
Survival_Breakdown("SibSp")

# %%
Survival_Breakdown("Parch")

# %%
Survival_Breakdown("Embarked")

# %%
female_data = df.loc[passengers["Sex"] == "female"]
female_age = female_data["Age"].dropna()
sns.histplot(data = female_age, kde = True)
plt.title("Age of Female Passengers")

# %% [markdown]
# # References
#
# [1]: Titanic_dataset csv by fyyying : https://gist.github.com/fyyying/4aa5b471860321d7b47fd881898162b7
#
# [2]: Titanic Wiki: https://en.wikipedia.org/wiki/Titanic
